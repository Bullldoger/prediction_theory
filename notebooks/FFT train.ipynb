# %%
import numpy as np

# %%
T = np.pi * 2
num = 10

# %%
x = np.linspace(0, T, num=num)
y = np.sin(x) + np.random.randn(num) / 10

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y, 'g')
plt.show()

# %%
fft_y = np.fft.fft(y)

# %%
plt.figure(figsize=(16, 10))
plt.plot(y, 'r')
plt.plot((np.sin(fft.imag) + np.cos(fft.imag)), 'g')
plt.show()

# %%
fft = np.fft.fft(y)

# %%
# Out:
# array([ 1.        ,  0.11039875,  0.32722956, -0.89651399,  0.49775558,
#         1.        ,  0.49775558, -0.89651399,  0.32722956,  0.11039875])
